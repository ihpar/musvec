# %%
from collections import Counter
import glob

# %%
file_list = glob.glob("data/txt/*.txt")

# %%
makam_counts = Counter()
for file in file_list:
    makam = (file.split("/")[2]).split("--")[0]
    makam_counts.update([makam])

# %%
makam_counts.most_common()
# Out:
# [('hicaz', 157),
#  ('nihavent', 130),
#  ('ussak', 118),
#  ('rast', 109),
#  ('huzzam', 96),
#  ('segah', 92),
#  ('huseyni', 92),
#  ('mahur', 88),
#  ('hicazkar', 79),
#  ('kurdilihicazkar', 70),
#  ('muhayyer', 67),
#  ('saba', 66),
#  ('acemasiran', 63),
#  ('beyati', 62),
#  ('buselik', 57),
#  ('karcigar', 53),
#  ('hicaz_humayun', 38),
#  ('acemkurdi', 37),
#  ('evic', 33),
#  ('muhayyerkurdi', 32),
#  ('tahir', 31),
#  ('gerdaniye', 26),
#  ('nisaburek', 26),
#  ('suzinak_zirgule', 26),
#  ('nikriz', 25),
#  ('sehnaz', 25),
#  ('sultaniyegah', 22),
#  ('yegah', 22),
#  ('neva', 21),
#  ('isfahan', 20),
#  ('hisarbuselik', 20),
#  ('suzidil', 19),
#  ('suzinak', 19),
#  ('ferahfeza', 17),
#  ('sedaraban', 15),
#  ('kurdi', 14),
#  ('bestenigar', 13),
#  ('ferahnak', 12),
#  ('hicaz_uzzal', 12),
#  ('sevkefza', 11),
#  ('evcara', 9),
#  ('zavil', 9),
#  ('sehnazbuselik', 8),
#  ('neveser', 8),
#  ('acem', 7),
#  ('beyati_araban', 7),
#  ('yeni_cargah', 7),
# ...
